# %% [markdown]
# # 1. Court Tracking — Instance Segmentation
#
# Trains a YOLO11-seg model to detect and segment volleyball court boundaries.
# The output mask is used downstream for camera calibration and 3D position mapping.
#
# | | |
# |---|---|
# | **Dataset** | [volleyball-court-seg v8](https://universe.roboflow.com/thesis-r4nbe/volleyball-court-seg/dataset/8) |
# | **Model** | `yolo11s-seg.pt` |
# | **Task** | Instance segmentation |
# | **Output** | `runs/segment/court-seg-v2/weights/best.pt` |
#
# > **Note on model size:** `yolo11s-seg` (small) is used instead of `n` (nano) because
# > segmentation needs more capacity to produce clean polygon masks. Switch to `m` or `l`
# > if your GPU has the VRAM headroom.

# %%
# ── CONFIGURATION ─────────────────────────────────────────────────
# Edit values here; all hyperparameters are in one place.

# Model
MODEL = "yolo11s-seg.pt"   # yolo11n/s/m/l/x-seg

# Training
EPOCHS      = 150
IMGSZ       = 640
BATCH       = 16
LR0         = 0.01          # initial LR
LRF         = 0.01          # final LR as fraction of LR0
COS_LR      = True          # cosine LR schedule (smoother than linear decay)
FREEZE      = 0             # freeze first N backbone layers (0 = off; try 10 for small datasets)
PATIENCE    = 20            # early-stop patience (epochs with no improvement)
SAVE_PERIOD = 10            # checkpoint every N epochs
WORKERS     = 4

# Data
DATASET_DIR  = "datasets/court_segmentation"
RF_WORKSPACE = "thesis-r4nbe"
RF_PROJECT   = "volleyball-court-seg"
RF_VERSION   = 8
RF_FORMAT    = "yolov8-obb"

# Run identity (used for both YOLO output dirs and W&B)
RUN_PROJECT   = "runs/segment"
RUN_NAME      = "court-seg-v2"
WANDB_PROJECT = "tobio"     # set to "" to skip W&B logging

# %%
import os
import wandb
from dotenv import load_dotenv
from roboflow import Roboflow
from ultralytics import YOLO
from ultralytics.data.converter import convert_coco

from utils import setup_device, print_metrics

# W&B first-time setup:
#   uv run wandb login   (enter API key from https://wandb.ai/settings)

load_dotenv()
DEVICE = setup_device()

if WANDB_PROJECT:
    wandb.init(
        project=WANDB_PROJECT,
        name=RUN_NAME,
        config={
            "model": MODEL, "epochs": EPOCHS, "imgsz": IMGSZ,
            "batch": BATCH, "lr0": LR0, "lrf": LRF, "cos_lr": COS_LR,
            "freeze": FREEZE, "dataset": f"{RF_PROJECT} v{RF_VERSION}",
        },
    )
# Out:
# GPU : NVIDIA GeForce RTX 3060
# CUDA: 11.8  |  PyTorch: 2.1.0+cu118
# Finishing previous runs because reinit is set to 'default'.
#  View run <strong style="color:#cdcd00">court-seg-v2</strong> at: <a href='https://wandb.ai/daniel-lu-projects/tobio/runs/ol329h4l' target="_blank">https://wandb.ai/daniel-lu-projects/tobio/runs/ol329h4l</a><br> View project at: <a href='https://wandb.ai/daniel-lu-projects/tobio' target="_blank">https://wandb.ai/daniel-lu-projects/tobio</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260417_120839-ol329h4l\logs</code>
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>d:\Coding\tobio\training\wandb\run-20260417_125448-cp3txzk9</code>
# Syncing run <strong><a href='https://wandb.ai/daniel-lu-projects/tobio/runs/cp3txzk9' target="_blank">court-seg-v2</a></strong> to <a href='https://wandb.ai/daniel-lu-projects/tobio' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/daniel-lu-projects/tobio' target="_blank">https://wandb.ai/daniel-lu-projects/tobio</a>
#  View run at <a href='https://wandb.ai/daniel-lu-projects/tobio/runs/cp3txzk9' target="_blank">https://wandb.ai/daniel-lu-projects/tobio/runs/cp3txzk9</a>

# %%
# Download dataset from Roboflow (safe to re-run — Roboflow skips if already present)
rf = Roboflow(api_key=os.getenv("ROBOFLOW_API_KEY"))
dataset = (
    rf.workspace(RF_WORKSPACE)
    .project(RF_PROJECT)
    .version(RF_VERSION)
    .download(RF_FORMAT, location=DATASET_DIR)
)
print(f"Dataset location: {dataset.location}")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in datasets/court_segmentation to yolov8-obb: 100% [618570378 / 618570378] bytes
# Extracting Dataset Version Zip to datasets/court_segmentation in yolov8-obb:: 100%|██████████| 19183/19183 [00:36<00:00, 526.97it/s]
# Dataset location: d:\Coding\tobio\training\datasets\court_segmentation

# %%
model = YOLO(MODEL)

train_results = model.train(
    data=os.path.join(DATASET_DIR, "data.yaml"),
    epochs=EPOCHS,
    imgsz=IMGSZ,
    batch=BATCH,
    device=DEVICE,
    workers=WORKERS,
    optimizer="Adam",
    lr0=LR0,
    lrf=LRF,
    cos_lr=COS_LR,
    freeze=FREEZE,
    patience=PATIENCE,
    project=RUN_PROJECT,
    name=RUN_NAME,
    save=True,
    save_period=SAVE_PERIOD,
    exist_ok=True,
    verbose=True,
    plots=True,
    val=True,
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.38 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.37  Python-3.10.11 torch-2.1.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=datasets/court_segmentation\data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=150, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=0, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s-seg.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=court-seg-v2, nbs=64, nms=False, opset=None, optimize=False, optimizer=Adam, overlap_mask=True, patience=20, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs/segment, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=D:\Coding\tobio\runs\segment\runs\segment\court-seg-v2, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=segment, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# TensorBoard: Start with 'tensorboard --logdir D:\Coding\tobio\runs\segment\runs\segment\court-seg-v2', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1   1474678  ultralytics.nn.modules.head.Segment          [2, 32, 128, 16, None, [128, 256, 512]]
# YOLO11s-seg summary: 204 layers, 10,083,062 parameters, 10,083,046 gradients, 33.1 GFLOPs
#
# Transferred 555/561 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 3.0MB/s 1.8s.8s<0.0s.4s
# AMP: checks passed
# train: Fast image access  (ping: 0.20.0 ms, read: 4.42.5 MB/s, size: 64.1 KB)
# train: Scanning D:\Coding\tobio\training\datasets\court_segmentation\train\labels... 6725 images, 1 backgrounds, 387 corrupt: 100% ━━━━━━━━━━━━ 6725/6725 197.8it/s 34.0s<0.1s
# train: D:\Coding\tobio\training\datasets\court_segmentation\train\images\0202_PNG_jpg.rf.20599e5c6d98b8ac78801c5584e6e935.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0775]
# train: D:\Coding\tobio\training\datasets\court_segmentation\train\images\0fb7cc05559aaeb5_jpg.rf.8f2b058457ec3ecb86c2f0f0cad2324c.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0311]
# train: D:\Coding\tobio\training\datasets\court_segmentation\train\images\0fb7cc05559aaeb5_jpg.rf.a459a6cfe39ca31eb8799a3feb2f9a5c.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0311]
# train: D:\Coding\tobio\training\datasets\court_segmentation\train\images\0fb7cc05559aaeb5_jpg.rf.d4fb0307f0ccc6d649c8de0e261ccfe5.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0311]
# train: D:\Coding\tobio\training\datasets\court_segmentation\train\images\1000_jpg.rf.37040a749e88549d3bd7eb8f6f65d6a5.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0233]
# train: D:\Coding\tobio\training\datasets\court_segmentation\train\images\1003_jpg.rf.b923261bf8046163d101e6d9893a47d1.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0296]
# train: D:\Coding\tobio\training\datasets\court_segmentation\train\images\
0+cu118 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 3
#       1 model = YOLO(MODEL)
# ----> 3 train_results = model.train(
#       4     data=os.path.join(DATASET_DIR, "data.yaml"),
#       5     epochs=EPOCHS,
#       6     imgsz=IMGSZ,
#       7     batch=BATCH,
#       8     device=DEVICE,
#       9     workers=WORKERS,
#      10     optimizer="Adam",
#      11     lr0=LR0,
#      12     lrf=LRF,
#      13     cos_lr=COS_LR,
#      14     freeze=FREEZE,
#      15     patience=PATIENCE,
#      16     project=RUN_PROJECT,
#      17     name=RUN_NAME,
#      18     save=True,
#      19     save_period=SAVE_PERIOD,
#      20     exist_ok=True,
#      21     verbose=True,
#      22     plots=True,
#      23     val=True,
#      24 )
#
# File d:\Coding\tobio\.venv\lib\site-packages\ultralytics\engine\model.py:787, in train(self, trainer, **kwargs)
#
# File d:\Coding\tobio\.venv\lib\site-packages\ultralytics\engine\trainer.py:246, in BaseTrainer.train(self)
#     243             ddp_cleanup(self, str(file))
#     245 else:
# --> 246     self._do_train()
#
# File d:\Coding\tobio\.venv\lib\site-packages\ultralytics\engine\trainer.py:564, in BaseTrainer._do_train(self)
#     562 LOGGER.info(f"\n{epoch - self.start_epoch + 1} epochs completed in {seconds / 3600:.3f} hours.")
#     563 # Do final val with best.pt
# --> 564 self.final_eval()
#     565 if RANK in {-1, 0}:
#     566     if self.args.plots:
#
# File d:\Coding\tobio\.venv\lib\site-packages\ultralytics\engine\trainer.py:850, in BaseTrainer.final_eval(self)
#     848 self.validator.args.plots = self.args.plots
#     849 self.validator.args.compile = False  # disable final val compile as too slow
# --> 850 self.metrics = self.validator(model=model)
#     851 self.metrics.pop("fitness", None)
#     852 self.run_callbacks("on_fit_epoch_end")
#
# File d:\Coding\tobio\.venv\lib\site-packages\torch\utils\_contextlib.py:115, in decorate_context(*args, **kwargs)
#
# File d:\Coding\tobio\.venv\lib\site-packages\ultralytics\engine\validator.py:168, in __call__(self, trainer, model)
#
# File d:\Coding\tobio\.venv\lib\site-packages\torch\utils\_contextlib.py:115, in decorate_context(*args, **kwargs)
#
# File d:\Coding\tobio\.venv\lib\site-packages\ultralytics\nn\autobackend.py:182, in __init__(self, model, device, dnn, data, fp16, fuse, verbose)
#
# File d:\Coding\tobio\.venv\lib\site-packages\ultralytics\nn\autobackend.py:327, in _model_type(p, dnn)
#
# ModuleNotFoundError: No module named 'ultralytics.engine.exporter'

# %%
# augment=True enables Test-Time Augmentation (TTA): runs at multiple scales/flips
# and merges predictions. Typically +1-3% mAP at ~3x inference cost.
metrics = model.val(augment=True)
print_metrics(metrics, task="segment")

# View training curves locally:
#   tensorboard --logdir runs/segment
# View in W&B: https://wandb.ai/

# %%
onnx_path = model.export(format="onnx")
print(f"ONNX model saved to: {onnx_path}")

if WANDB_PROJECT:
    wandb.finish()
